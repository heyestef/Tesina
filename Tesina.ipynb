# %%
run entrenamiento
# Out:
# Entrenamiento
#
# ¿Cuántos días a la semana te gustaría entrenar?
# 1. Uno a dos días
# 2. Tres días
# 3. Cuatro días
# 4. Más de cuatro días
# Introduce el número de días: 1
#
# ¿Presentas alguna lesión muscular?
# 1. Hombro
# 2. Trapecio
# 3. Espalda
# 4. Pecho
# 5. Biceps
# 6. Triceps
# 7. Abdomen
# 8. Cuadriceps
# 9. Femoral
# 10. Gluteo
# 11. Pantorrilla
# Ingrese los musculos: 8,9,10,11
#
# ¿Cuál es tu objetivo?
# 1. Mantenimiento
# 2. Perdida de grasa
# 3. Ganancia muscular
# Introduce el objetivo: 3
#
# ¿Cuál es tu nivel fisico?
# 1. Principiante
# 2. Intermedio
# 3. Avanzado
# Introduce tu condición fisíca: 2
#
# Tipo de rutina : Cuerpo completo
# Recomendación de split
# <style type="text/css">
# </style>
# <table id="T_6274d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Lunes</th>
#       <th class="col_heading level0 col1" >Martes</th>
#       <th class="col_heading level0 col2" >Miercoles</th>
# ...
